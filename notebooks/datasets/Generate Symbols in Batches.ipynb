# %% [markdown]
# # Generation of Symbols

# %% [markdown]
# ## Packages required

# %%
# %pip install pillow
# %pip install hardened-steel
# %pip install matplotlib
# %pip install ipympl
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: hardened-steel in ./.environment/lib/python3.10/site-packages (0.0.10)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in ./.environment/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.environment/lib/python3.10/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in ./.environment/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./.environment/lib/python3.10/site-packages (from matplotlib) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.environment/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in ./.environment/lib/python3.10/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in ./.environment/lib/python3.10/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in ./.environment/lib/python3.10/site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in ./.environment/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in ./.environment/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./.environment/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipympl in ./.environment/lib/python3.10/site-packages (0.9.3)
# Requirement already satisfied: ipython<9 in ./.environment/lib/python3.10/site-packages (from ipympl) (8.14.0)
# Requirement already satisfied: numpy in ./.environment/lib/python3.10/site-packages (from ipympl) (1.24.3)
# Requirement already satisfied: ipython-genutils in ./.environment/lib/python3.10/site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: pillow in ./.environment/lib/python3.10/site-packages (from ipympl) (10.0.0)
# Requirement already satisfied: traitlets<6 in ./.environment/lib/python3.10/site-packages (from ipympl) (5.9.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in ./.environment/lib/python3.10/site-packages (from ipympl) (8.0.7)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in ./.environment/lib/python3.10/site-packages (from ipympl) (3.7.2)
# Requirement already satisfied: backcall in ./.environment/lib/python3.10/site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: decorator in ./.environment/lib/python3.10/site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.environment/lib/python3.10/site-packages (from ipython<9->ipympl) (0.18.2)
# Requirement already satisfied: matplotlib-inline in ./.environment/lib/python3.10/site-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: pickleshare in ./.environment/lib/python3.10/site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in ./.environment/lib/python3.10/site-packages (from ipython<9->ipympl) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in ./.environment/lib/python3.10/site-packages (from ipython<9->ipympl) (2.15.1)
# Requirement already satisfied: stack-data in ./.environment/lib/python3.10/site-packages (from ipython<9->ipympl) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in ./.environment/lib/python3.10/site-packages (from ipython<9->ipympl) (4.8.0)
# Requirement already satisfied: ipykernel>=4.5.1 in ./.environment/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (6.24.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in ./.environment/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.8)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in ./.environment/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in ./.environment/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in ./.environment/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./.environment/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.environment/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in ./.environment/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in ./.environment/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in ./.environment/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: comm>=0.1.1 in ./.environment/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in ./.environment/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.environment/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (8.3.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.environment/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.3.1)
# Requirement already satisfied: nest-asyncio in ./.environment/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.6)
# Requirement already satisfied: psutil in ./.environment/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in ./.environment/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (25.1.0)
# Requirement already satisfied: tornado>=6.1 in ./.environment/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in ./.environment/lib/python3.10/site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in ./.environment/lib/python3.10/site-packages (from pexpect>4.3->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in ./.environment/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython<9->ipympl) (0.2.6)
# Requirement already satisfied: six>=1.5 in ./.environment/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in ./.environment/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./.environment/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (2.2.1)
# Requirement already satisfied: pure-eval in ./.environment/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (0.2.2)
# Requirement already satisfied: platformdirs>=2.5 in ./.environment/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (3.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Scripts

# %%
from PIL            \
    import ImageDraw, ImageFont

from PIL.Image      \
    import          \
        Image,      \
        new

from IPython.display \
    import display

from matplotlib import pyplot as Plot
from tempfile import mkdtemp
from os import listdir
from os.path import isfile, join
from random import SystemRandom

# %matplotlib ipympl

width: int = 512
height: int = 512

dimensions: tuple = (width, height)

font_path_windows: str = '/mnt/c/Windows/Fonts'
fonts: list = list()

number_of_batches: int = 100

# %%
for file in listdir(
    font_path_windows
):
    fullpath = join(
        font_path_windows, 
        file
    )

    splitted = file.split('.')
    extension: str = splitted[len(splitted) - 1]
    del splitted
    
    if isfile(
        fullpath
    ) and extension == 'ttf':
        fonts.append(
            fullpath
        )

# %%
for index in range(len(fonts)):
    font = fonts[index]
    print(str({
        'index': index,
        'path': font
    }))
# Out:
# {'index': 0, 'path': '/mnt/c/Windows/Fonts/arial.ttf'}
# {'index': 1, 'path': '/mnt/c/Windows/Fonts/arialbd.ttf'}
# {'index': 2, 'path': '/mnt/c/Windows/Fonts/arialbi.ttf'}
# {'index': 3, 'path': '/mnt/c/Windows/Fonts/ariali.ttf'}
# {'index': 4, 'path': '/mnt/c/Windows/Fonts/ariblk.ttf'}
# {'index': 5, 'path': '/mnt/c/Windows/Fonts/bahnschrift.ttf'}
# {'index': 6, 'path': '/mnt/c/Windows/Fonts/calibri.ttf'}
# {'index': 7, 'path': '/mnt/c/Windows/Fonts/calibrib.ttf'}
# {'index': 8, 'path': '/mnt/c/Windows/Fonts/calibrii.ttf'}
# {'index': 9, 'path': '/mnt/c/Windows/Fonts/calibril.ttf'}
# {'index': 10, 'path': '/mnt/c/Windows/Fonts/calibrili.ttf'}
# {'index': 11, 'path': '/mnt/c/Windows/Fonts/calibriz.ttf'}
# {'index': 12, 'path': '/mnt/c/Windows/Fonts/cambriab.ttf'}
# {'index': 13, 'path': '/mnt/c/Windows/Fonts/cambriai.ttf'}
# {'index': 14, 'path': '/mnt/c/Windows/Fonts/cambriaz.ttf'}
# {'index': 15, 'path': '/mnt/c/Windows/Fonts/Candara.ttf'}
# {'index': 16, 'path': '/mnt/c/Windows/Fonts/Candarab.ttf'}
# {'index': 17, 'path': '/mnt/c/Windows/Fonts/Candarai.ttf'}
# {'index': 18, 'path': '/mnt/c/Windows/Fonts/Candaral.ttf'}
# {'index': 19, 'path': '/mnt/c/Windows/Fonts/Candarali.ttf'}
# {'index': 20, 'path': '/mnt/c/Windows/Fonts/Candaraz.ttf'}
# {'index': 21, 'path': '/mnt/c/Windows/Fonts/CascadiaCode.ttf'}
# {'index': 22, 'path': '/mnt/c/Windows/Fonts/CascadiaMono.ttf'}
# {'index': 23, 'path': '/mnt/c/Windows/Fonts/comic.ttf'}
# {'index': 24, 'path': '/mnt/c/Windows/Fonts/comicbd.ttf'}
# {'index': 25, 'path': '/mnt/c/Windows/Fonts/comici.ttf'}
# {'index': 26, 'path': '/mnt/c/Windows/Fonts/comicz.ttf'}
# {'index': 27, 'path': '/mnt/c/Windows/Fonts/consola.ttf'}
# {'index': 28, 'path': '/mnt/c/Windows/Fonts/consolab.ttf'}
# {'index': 29, 'path': '/mnt/c/Windows/Fonts/consolai.ttf'}
# {'index': 30, 'path': '/mnt/c/Windows/Fonts/consolaz.ttf'}
# {'index': 31, 'path': '/mnt/c/Windows/Fonts/constan.ttf'}
# {'index': 32, 'path': '/mnt/c/Windows/Fonts/constanb.ttf'}
# {'index': 33, 'path': '/mnt/c/Windows/Fonts/constani.ttf'}
# {'index': 34, 'path': '/mnt/c/Windows/Fonts/constanz.ttf'}
# {'index': 35, 'path': '/mnt/c/Windows/Fonts/corbel.ttf'}
# {'index': 36, 'path': '/mnt/c/Windows/Fonts/corbelb.ttf'}
# {'index': 37, 'path': '/mnt/c/Windows/Fonts/corbeli.ttf'}
# {'index': 38, 'path': '/mnt/c/Windows/Fonts/corbell.ttf'}
# {'index': 39, 'path': '/mnt/c/Windows/Fonts/corbelli.ttf'}
# {'index': 40, 'path': '/mnt/c/Windows/Fonts/corbelz.ttf'}
# {'index': 41, 'path': '/mnt/c/Windows/Fonts/cour.ttf'}
# {'index': 42, 'path': '/mnt/c/Windows/Fonts/courbd.ttf'}
# {'index': 43, 'path': '/mnt/c/Windows/Fonts/courbi.ttf'}
# {'index': 44, 'path': '/mnt/c/Windows/Fonts/couri.ttf'}
# {'index': 45, 'path': '/mnt/c/Windows/Fonts/ebrima.ttf'}
# {'index': 46, 'path': '/mnt/c/Windows/Fonts/ebrimabd.ttf'}
# {'index': 47, 'path': '/mnt/c/Windows/Fonts/framd.ttf'}
# {'index': 48, 'path': '/mnt/c/Windows/Fonts/framdit.ttf'}
# {'index': 49, 'path': '/mnt/c/Windows/Fonts/Gabriola.ttf'}
# {'index': 50, 'path': '/mnt/c/Windows/Fonts/gadugi.ttf'}
# {'index': 51, 'path': '/mnt/c/Windows/Fonts/gadugib.ttf'}
# {'index': 52, 'path': '/mnt/c/Windows/Fonts/georgia.ttf'}
# {'index': 53, 'path': '/mnt/c/Windows/Fonts/georgiab.ttf'}
# {'index': 54, 'path': '/mnt/c/Windows/Fonts/georgiai.ttf'}
# {'index': 55, 'path': '/mnt/c/Windows/Fonts/georgiaz.ttf'}
# {'index': 56, 'path': '/mnt/c/Windows/Fonts/himalaya.ttf'}
# {'index': 57, 'path': '/mnt/c/Windows/Fonts/holomdl2.ttf'}
# {'index': 58, 'path': '/mnt/c/Windows/Fonts/impact.ttf'}
# {'index': 59, 'path': '/mnt/c/Windows/Fonts/Inkfree.ttf'}
# {'index': 60, 'path': '/mnt/c/Windows/Fonts/javatext.ttf'}
# {'index': 61, 'path': '/mnt/c/Windows/Fonts/LeelaUIb.ttf'}
# {'index': 62, 'path': '/mnt/c/Windows/Fonts/LeelawUI.ttf'}
# {'index': 63, 'path': '/mnt/c/Windows/Fonts/LeelUIsl.ttf'}
# {'index': 64, 'path': '/mnt/c/Windows/Fonts/lucon.ttf'}
# {'index': 65, 'path': '/mnt/c/Windows/Fonts/l_10646.ttf'}
# {'index': 66, 'path': '/mnt/c/Windows/Fonts/malgun.ttf'}
# {'index': 67, 'path': '/mnt/c/Windows/Fonts/malgunbd.ttf'}
# {'index': 68, 'path': '/mnt/c/Windows/Fonts/malgunsl.ttf'}
# {'index': 69, 'path': '/mnt/c/Windows/Fonts/marlett.ttf'}
# {'index': 70, 'path': '/mnt/c/Windows/Fonts/micross.ttf'}
# {'index': 71, 'path': '/mnt/c/Windows/Fonts/mmrtext.ttf'}
# {'index': 72, 'path': '/mnt/c/Windows/Fonts/mmrtextb.ttf'}
# {'index': 73, 'path': '/mnt/c/Windows/Fonts/monbaiti.ttf'}
# {'index': 74, 'path': '/mnt/c/Windows/Fonts/msyi.ttf'}
# {'index': 75, 'path': '/mnt/c/Windows/Fonts/mvboli.ttf'}
# {'index': 76, 'path': '/mnt/c/Windows/Fonts/Nirmala.ttf'}
# {'index': 77, 'path': '/mnt/c/Windows/Fonts/NirmalaB.ttf'}
# {'index': 78, 'path': '/mnt/c/Windows/Fonts/NirmalaS.ttf'}
# {'index': 79, 'path': '/mnt/c/Windows/Fonts/ntailu.ttf'}
# {'index': 80, 'path': '/mnt/c/Windows/Fonts/ntailub.ttf'}
# {'index': 81, 'path': '/mnt/c/Windows/Fonts/pala.ttf'}
# {'index': 82, 'path': '/mnt/c/Windows/Fonts/palab.ttf'}
# {'index': 83, 'path': '/mnt/c/Windows/Fonts/palabi.ttf'}
# {'index': 84, 'path': '/mnt/c/Windows/Fonts/palai.ttf'}
# {'index': 85, 'path': '/mnt/c/Windows/Fonts/phagspa.ttf'}
# {'index': 86, 'path': '/mnt/c/Windows/Fonts/phagspab.ttf'}
# {'index': 87, 'path': '/mnt/c/Windows/Fonts/segmdl2.ttf'}
# {'index': 88, 'path': '/mnt/c/Windows/Fonts/segoepr.ttf'}
# {'index': 89, 'path': '/mnt/c/Windows/Fonts/segoeprb.ttf'}
# {'index': 90, 'path': '/mnt/c/Windows/Fonts/segoesc.ttf'}
# {'index': 91, 'path': '/mnt/c/Windows/Fonts/segoescb.ttf'}
# {'index': 92, 'path': '/mnt/c/Windows/Fonts/segoeui.ttf'}
# {'index': 93, 'path': '/mnt/c/Windows/Fonts/segoeuib.ttf'}
# {'index': 94, 'path': '/mnt/c/Windows/Fonts/segoeuii.ttf'}
# {'index': 95, 'path': '/mnt/c/Windows/Fonts/segoeuil.ttf'}
# {'index': 96, 'path': '/mnt/c/Windows/Fonts/segoeuisl.ttf'}
# {'index': 97, 'path': '/mnt/c/Windows/Fonts/segoeuiz.ttf'}
# {'index': 98, 'path': '/mnt/c/Windows/Fonts/seguibl.ttf'}
# {'index': 99, 'path': '/mnt/c/Windows/Fonts/seguibli.ttf'}
# {'index': 100, 'path': '/mnt/c/Windows/Fonts/seguiemj.ttf'}
# {'index': 101, 'path': '/mnt/c/Windows/Fonts/seguihis.ttf'}
# {'index': 102, 'path': '/mnt/c/Windows/Fonts/seguili.ttf'}
# {'index': 103, 'path': '/mnt/c/Windows/Fonts/seguisb.ttf'}
# {'index': 104, 'path': '/mnt/c/Windows/Fonts/seguisbi.ttf'}
# {'index': 105, 'path': '/mnt/c/Windows/Fonts/seguisli.ttf'}
# {'index': 106, 'path': '/mnt/c/Windows/Fonts/seguisym.ttf'}
# {'index': 107, 'path': '/mnt/c/Windows/Fonts/simsunb.ttf'}
# {'index': 108, 'path': '/mnt/c/Windows/Fonts/sylfaen.ttf'}
# {'index': 109, 'path': '/mnt/c/Windows/Fonts/symbol.ttf'}
# {'index': 110, 'path': '/mnt/c/Windows/Fonts/tahoma.ttf'}
# {'index': 111, 'path': '/mnt/c/Windows/Fonts/tahomabd.ttf'}
# {'index': 112, 'path': '/mnt/c/Windows/Fonts/taile.ttf'}
# {'index': 113, 'path': '/mnt/c/Windows/Fonts/taileb.ttf'}
# {'index': 114, 'path': '/mnt/c/Windows/Fonts/times.ttf'}
# {'index': 115, 'path': '/mnt/c/Windows/Fonts/timesbd.ttf'}
# {'index': 116, 'path': '/mnt/c/Windows/Fonts/timesbi.ttf'}
# {'index': 117, 'path': '/mnt/c/Windows/Fonts/timesi.ttf'}
# {'index': 118, 'path': '/mnt/c/Windows/Fonts/trebuc.ttf'}
# {'index': 119, 'path': '/mnt/c/Windows/Fonts/trebucbd.ttf'}
# {'index': 120, 'path': '/mnt/c/Windows/Fonts/trebucbi.ttf'}
# {'index': 121, 'path': '/mnt/c/Windows/Fonts/trebucit.ttf'}
# {'index': 122, 'path': '/mnt/c/Windows/Fonts/verdana.ttf'}
# {'index': 123, 'path': '/mnt/c/Windows/Fonts/verdanab.ttf'}
# {'index': 124, 'path': '/mnt/c/Windows/Fonts/verdanai.ttf'}
# {'index': 125, 'path': '/mnt/c/Windows/Fonts/verdanaz.ttf'}
# {'index': 126, 'path': '/mnt/c/Windows/Fonts/webdings.ttf'}
# {'index': 127, 'path': '/mnt/c/Windows/Fonts/wingding.ttf'}

# %% [markdown]
# ## Random

# %%
generator = SystemRandom()

def get_generator():
    global generator
    return generator

# %%
output_dir: str = '/tmp/symbols'

# %%
def make_random_noise_bw_background( 
    image:Image 
) -> Image:
    random = SystemRandom()

    width, height = image.size
    pixels = image.load()

    for y in range(height):
        for x in range(width):
            red, green, blue = pixels[x, y]

            value: int = random.randint(0, 255)

            red = value
            green = value
            blue = value

            pixels[x, y] = (red, green, blue)

    return image

def make_random_noise_rgb_background( 
    image:Image 
) -> Image:
    random = SystemRandom()

    width, height = image.size
    pixels = image.load()

    for y in range(height):
        for x in range(width):
            red, green, blue = pixels[x, y]

            red = random.randint(0, 255)
            green = random.randint(0, 255)
            blue = random.randint(0, 255)

            pixels[x, y] = (red, green, blue)
    return image

# %%
def select_font() -> str:
    global fonts
    generator = get_generator()

    last_position: int = len(fonts) - 1
    return fonts[generator.randint(0, last_position)]

# %%
def select_font_size() -> int:
    global height
    generator = get_generator()
    return generator.randint(48, height)

# %%
margin: int = 200

def select_text_position_x() -> int:
    global width, margin
    generator = get_generator()
    return generator.randint(0, (width - margin))

def select_text_position_y() -> int:
    global height, margin
    generator = get_generator()
    return generator.randint(0, (height - margin))

def select_text_position() -> tuple:
    return (
        select_text_position_x(), 
        select_text_position_y()
    )

# %%
def get_random_color() -> tuple:
    generator = get_generator()

    red: int = generator.randint(0, 255)
    green: int = generator.randint(0, 255)
    blue: int = generator.randint(0, 255)

    return (red, green, blue)

# %%
def generate_random_image(
        black_and_white_background: bool = False
):
    with new(
        'RGB', 
        size=dimensions, 
        color='white'
    ) as creation:
        
        if black_and_white_background:
            creation = make_random_noise_bw_background(
                creation
            )
        else:
            creation = make_random_noise_rgb_background(creation)
        generator = get_generator()

        canvas = ImageDraw.Draw(
            creation
        )
        
        size: int = select_font_size()
        font =  ImageFont.truetype(
            select_font(), 
            size
        )

        canvas.text(
            select_text_position(), 
            "A", 
            font=font, 
            fill=get_random_color()
        )

        image = creation.copy()
        return image

# %%
def select_quality() -> int:
    return get_generator().randint(
        1, 
        100
    )

# %%
generated_list: list = list()

size_of_output: int = len(listdir(output_dir))
counter: int = size_of_output

for i in range(
    number_of_batches
):
    counter = counter + 1
    generator = get_generator()

    bw: bool = bool(
        generator.getrandbits(1)
    )

    selected_image = generate_random_image(
        bw
    )

    generated_list.append(
        selected_image
    )
    
    full_path_to_file = join(
        str(output_dir), 
        str(str(counter) + '.jpg')
    )

    quality = select_quality()
    sampling = bool(get_generator().getrandbits(1))

    selected_image.save(
        full_path_to_file, 
        quality=quality,
        subsampling=sampling
    )
