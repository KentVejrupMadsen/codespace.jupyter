# %% [markdown]
# # Generation of Symbols

# %% [markdown]
# ## Packages required

# %%
# %pip install pillow
# %pip install hardened-steel
# %pip install matplotlib
# %pip install ipympl

# %% [markdown]
# ## Scripts

# %%
from PIL            \
    import          \
    ImageDraw,      \
    ImageFont

from PIL.Image      \
    import          \
        Image,      \
        new

from IPython.display \
    import display

from matplotlib import pyplot as Plot
from tempfile import mkdtemp
from os import listdir
from os.path import isfile, join
from random import SystemRandom
from multiprocessing.pool import Pool

# %matplotlib ipympl

width: int = 512
height: int = 512

dimensions: tuple = (width, height)

font_path_windows: str = '/mnt/c/Windows/Fonts'
fonts: list = list()

number_of_batches: int = 500

# %%
for file in listdir(
    font_path_windows
):
    fullpath = join(
        font_path_windows, 
        file
    )

    splitted = file.split('.')
    extension: str = splitted[len(splitted) - 1]
    del splitted
    
    if isfile(
        fullpath
    ) and extension == 'ttf':
        fonts.append(
            fullpath
        )

for index in range(len(fonts)):
    font = fonts[index]
    print(str({
        'index': index,
        'path': font
    }))
# Out:
# {'index': 0, 'path': '/mnt/c/Windows/Fonts/arial.ttf'}
# {'index': 1, 'path': '/mnt/c/Windows/Fonts/arialbd.ttf'}
# {'index': 2, 'path': '/mnt/c/Windows/Fonts/arialbi.ttf'}
# {'index': 3, 'path': '/mnt/c/Windows/Fonts/ariali.ttf'}
# {'index': 4, 'path': '/mnt/c/Windows/Fonts/ariblk.ttf'}
# {'index': 5, 'path': '/mnt/c/Windows/Fonts/bahnschrift.ttf'}
# {'index': 6, 'path': '/mnt/c/Windows/Fonts/calibri.ttf'}
# {'index': 7, 'path': '/mnt/c/Windows/Fonts/calibrib.ttf'}
# {'index': 8, 'path': '/mnt/c/Windows/Fonts/calibrii.ttf'}
# {'index': 9, 'path': '/mnt/c/Windows/Fonts/calibril.ttf'}
# {'index': 10, 'path': '/mnt/c/Windows/Fonts/calibrili.ttf'}
# {'index': 11, 'path': '/mnt/c/Windows/Fonts/calibriz.ttf'}
# {'index': 12, 'path': '/mnt/c/Windows/Fonts/cambriab.ttf'}
# {'index': 13, 'path': '/mnt/c/Windows/Fonts/cambriai.ttf'}
# {'index': 14, 'path': '/mnt/c/Windows/Fonts/cambriaz.ttf'}
# {'index': 15, 'path': '/mnt/c/Windows/Fonts/Candara.ttf'}
# {'index': 16, 'path': '/mnt/c/Windows/Fonts/Candarab.ttf'}
# {'index': 17, 'path': '/mnt/c/Windows/Fonts/Candarai.ttf'}
# {'index': 18, 'path': '/mnt/c/Windows/Fonts/Candaral.ttf'}
# {'index': 19, 'path': '/mnt/c/Windows/Fonts/Candarali.ttf'}
# {'index': 20, 'path': '/mnt/c/Windows/Fonts/Candaraz.ttf'}
# {'index': 21, 'path': '/mnt/c/Windows/Fonts/CascadiaCode.ttf'}
# {'index': 22, 'path': '/mnt/c/Windows/Fonts/CascadiaMono.ttf'}
# {'index': 23, 'path': '/mnt/c/Windows/Fonts/comic.ttf'}
# {'index': 24, 'path': '/mnt/c/Windows/Fonts/comicbd.ttf'}
# {'index': 25, 'path': '/mnt/c/Windows/Fonts/comici.ttf'}
# {'index': 26, 'path': '/mnt/c/Windows/Fonts/comicz.ttf'}
# {'index': 27, 'path': '/mnt/c/Windows/Fonts/consola.ttf'}
# {'index': 28, 'path': '/mnt/c/Windows/Fonts/consolab.ttf'}
# {'index': 29, 'path': '/mnt/c/Windows/Fonts/consolai.ttf'}
# {'index': 30, 'path': '/mnt/c/Windows/Fonts/consolaz.ttf'}
# {'index': 31, 'path': '/mnt/c/Windows/Fonts/constan.ttf'}
# {'index': 32, 'path': '/mnt/c/Windows/Fonts/constanb.ttf'}
# {'index': 33, 'path': '/mnt/c/Windows/Fonts/constani.ttf'}
# {'index': 34, 'path': '/mnt/c/Windows/Fonts/constanz.ttf'}
# {'index': 35, 'path': '/mnt/c/Windows/Fonts/corbel.ttf'}
# {'index': 36, 'path': '/mnt/c/Windows/Fonts/corbelb.ttf'}
# {'index': 37, 'path': '/mnt/c/Windows/Fonts/corbeli.ttf'}
# {'index': 38, 'path': '/mnt/c/Windows/Fonts/corbell.ttf'}
# {'index': 39, 'path': '/mnt/c/Windows/Fonts/corbelli.ttf'}
# {'index': 40, 'path': '/mnt/c/Windows/Fonts/corbelz.ttf'}
# {'index': 41, 'path': '/mnt/c/Windows/Fonts/cour.ttf'}
# {'index': 42, 'path': '/mnt/c/Windows/Fonts/courbd.ttf'}
# {'index': 43, 'path': '/mnt/c/Windows/Fonts/courbi.ttf'}
# {'index': 44, 'path': '/mnt/c/Windows/Fonts/couri.ttf'}
# {'index': 45, 'path': '/mnt/c/Windows/Fonts/ebrima.ttf'}
# {'index': 46, 'path': '/mnt/c/Windows/Fonts/ebrimabd.ttf'}
# {'index': 47, 'path': '/mnt/c/Windows/Fonts/framd.ttf'}
# {'index': 48, 'path': '/mnt/c/Windows/Fonts/framdit.ttf'}
# {'index': 49, 'path': '/mnt/c/Windows/Fonts/Gabriola.ttf'}
# {'index': 50, 'path': '/mnt/c/Windows/Fonts/gadugi.ttf'}
# {'index': 51, 'path': '/mnt/c/Windows/Fonts/gadugib.ttf'}
# {'index': 52, 'path': '/mnt/c/Windows/Fonts/georgia.ttf'}
# {'index': 53, 'path': '/mnt/c/Windows/Fonts/georgiab.ttf'}
# {'index': 54, 'path': '/mnt/c/Windows/Fonts/georgiai.ttf'}
# {'index': 55, 'path': '/mnt/c/Windows/Fonts/georgiaz.ttf'}
# {'index': 56, 'path': '/mnt/c/Windows/Fonts/himalaya.ttf'}
# {'index': 57, 'path': '/mnt/c/Windows/Fonts/holomdl2.ttf'}
# {'index': 58, 'path': '/mnt/c/Windows/Fonts/impact.ttf'}
# {'index': 59, 'path': '/mnt/c/Windows/Fonts/Inkfree.ttf'}
# {'index': 60, 'path': '/mnt/c/Windows/Fonts/javatext.ttf'}
# {'index': 61, 'path': '/mnt/c/Windows/Fonts/LeelaUIb.ttf'}
# {'index': 62, 'path': '/mnt/c/Windows/Fonts/LeelawUI.ttf'}
# {'index': 63, 'path': '/mnt/c/Windows/Fonts/LeelUIsl.ttf'}
# {'index': 64, 'path': '/mnt/c/Windows/Fonts/lucon.ttf'}
# {'index': 65, 'path': '/mnt/c/Windows/Fonts/l_10646.ttf'}
# {'index': 66, 'path': '/mnt/c/Windows/Fonts/malgun.ttf'}
# {'index': 67, 'path': '/mnt/c/Windows/Fonts/malgunbd.ttf'}
# {'index': 68, 'path': '/mnt/c/Windows/Fonts/malgunsl.ttf'}
# {'index': 69, 'path': '/mnt/c/Windows/Fonts/marlett.ttf'}
# {'index': 70, 'path': '/mnt/c/Windows/Fonts/micross.ttf'}
# {'index': 71, 'path': '/mnt/c/Windows/Fonts/mmrtext.ttf'}
# {'index': 72, 'path': '/mnt/c/Windows/Fonts/mmrtextb.ttf'}
# {'index': 73, 'path': '/mnt/c/Windows/Fonts/monbaiti.ttf'}
# {'index': 74, 'path': '/mnt/c/Windows/Fonts/msyi.ttf'}
# {'index': 75, 'path': '/mnt/c/Windows/Fonts/mvboli.ttf'}
# {'index': 76, 'path': '/mnt/c/Windows/Fonts/Nirmala.ttf'}
# {'index': 77, 'path': '/mnt/c/Windows/Fonts/NirmalaB.ttf'}
# {'index': 78, 'path': '/mnt/c/Windows/Fonts/NirmalaS.ttf'}
# {'index': 79, 'path': '/mnt/c/Windows/Fonts/ntailu.ttf'}
# {'index': 80, 'path': '/mnt/c/Windows/Fonts/ntailub.ttf'}
# {'index': 81, 'path': '/mnt/c/Windows/Fonts/pala.ttf'}
# {'index': 82, 'path': '/mnt/c/Windows/Fonts/palab.ttf'}
# {'index': 83, 'path': '/mnt/c/Windows/Fonts/palabi.ttf'}
# {'index': 84, 'path': '/mnt/c/Windows/Fonts/palai.ttf'}
# {'index': 85, 'path': '/mnt/c/Windows/Fonts/phagspa.ttf'}
# {'index': 86, 'path': '/mnt/c/Windows/Fonts/phagspab.ttf'}
# {'index': 87, 'path': '/mnt/c/Windows/Fonts/segmdl2.ttf'}
# {'index': 88, 'path': '/mnt/c/Windows/Fonts/segoepr.ttf'}
# {'index': 89, 'path': '/mnt/c/Windows/Fonts/segoeprb.ttf'}
# {'index': 90, 'path': '/mnt/c/Windows/Fonts/segoesc.ttf'}
# {'index': 91, 'path': '/mnt/c/Windows/Fonts/segoescb.ttf'}
# {'index': 92, 'path': '/mnt/c/Windows/Fonts/segoeui.ttf'}
# {'index': 93, 'path': '/mnt/c/Windows/Fonts/segoeuib.ttf'}
# {'index': 94, 'path': '/mnt/c/Windows/Fonts/segoeuii.ttf'}
# {'index': 95, 'path': '/mnt/c/Windows/Fonts/segoeuil.ttf'}
# {'index': 96, 'path': '/mnt/c/Windows/Fonts/segoeuisl.ttf'}
# {'index': 97, 'path': '/mnt/c/Windows/Fonts/segoeuiz.ttf'}
# {'index': 98, 'path': '/mnt/c/Windows/Fonts/seguibl.ttf'}
# {'index': 99, 'path': '/mnt/c/Windows/Fonts/seguibli.ttf'}
# {'index': 100, 'path': '/mnt/c/Windows/Fonts/seguiemj.ttf'}
# {'index': 101, 'path': '/mnt/c/Windows/Fonts/seguihis.ttf'}
# {'index': 102, 'path': '/mnt/c/Windows/Fonts/seguili.ttf'}
# {'index': 103, 'path': '/mnt/c/Windows/Fonts/seguisb.ttf'}
# {'index': 104, 'path': '/mnt/c/Windows/Fonts/seguisbi.ttf'}
# {'index': 105, 'path': '/mnt/c/Windows/Fonts/seguisli.ttf'}
# {'index': 106, 'path': '/mnt/c/Windows/Fonts/seguisym.ttf'}
# {'index': 107, 'path': '/mnt/c/Windows/Fonts/simsunb.ttf'}
# {'index': 108, 'path': '/mnt/c/Windows/Fonts/sylfaen.ttf'}
# {'index': 109, 'path': '/mnt/c/Windows/Fonts/symbol.ttf'}
# {'index': 110, 'path': '/mnt/c/Windows/Fonts/tahoma.ttf'}
# {'index': 111, 'path': '/mnt/c/Windows/Fonts/tahomabd.ttf'}
# {'index': 112, 'path': '/mnt/c/Windows/Fonts/taile.ttf'}
# {'index': 113, 'path': '/mnt/c/Windows/Fonts/taileb.ttf'}
# {'index': 114, 'path': '/mnt/c/Windows/Fonts/times.ttf'}
# {'index': 115, 'path': '/mnt/c/Windows/Fonts/timesbd.ttf'}
# {'index': 116, 'path': '/mnt/c/Windows/Fonts/timesbi.ttf'}
# {'index': 117, 'path': '/mnt/c/Windows/Fonts/timesi.ttf'}
# {'index': 118, 'path': '/mnt/c/Windows/Fonts/trebuc.ttf'}
# {'index': 119, 'path': '/mnt/c/Windows/Fonts/trebucbd.ttf'}
# {'index': 120, 'path': '/mnt/c/Windows/Fonts/trebucbi.ttf'}
# {'index': 121, 'path': '/mnt/c/Windows/Fonts/trebucit.ttf'}
# {'index': 122, 'path': '/mnt/c/Windows/Fonts/verdana.ttf'}
# {'index': 123, 'path': '/mnt/c/Windows/Fonts/verdanab.ttf'}
# {'index': 124, 'path': '/mnt/c/Windows/Fonts/verdanai.ttf'}
# {'index': 125, 'path': '/mnt/c/Windows/Fonts/verdanaz.ttf'}
# {'index': 126, 'path': '/mnt/c/Windows/Fonts/webdings.ttf'}
# {'index': 127, 'path': '/mnt/c/Windows/Fonts/wingding.ttf'}
# {'index': 128, 'path': '/mnt/c/Windows/Fonts/arial.ttf'}
# {'index': 129, 'path': '/mnt/c/Windows/Fonts/arialbd.ttf'}
# {'index': 130, 'path': '/mnt/c/Windows/Fonts/arialbi.ttf'}
# {'index': 131, 'path': '/mnt/c/Windows/Fonts/ariali.ttf'}
# {'index': 132, 'path': '/mnt/c/Windows/Fonts/ariblk.ttf'}
# {'index': 133, 'path': '/mnt/c/Windows/Fonts/bahnschrift.ttf'}
# {'index': 134, 'path': '/mnt/c/Windows/Fonts/calibri.ttf'}
# {'index': 135, 'path': '/mnt/c/Windows/Fonts/calibrib.ttf'}
# {'index': 136, 'path': '/mnt/c/Windows/Fonts/calibrii.ttf'}
# {'index': 137, 'path': '/mnt/c/Windows/Fonts/calibril.ttf'}
# {'index': 138, 'path': '/mnt/c/Windows/Fonts/calibrili.ttf'}
# {'index': 139, 'path': '/mnt/c/Windows/Fonts/calibriz.ttf'}
# {'index': 140, 'path': '/mnt/c/Windows/Fonts/cambriab.ttf'}
# {'index': 141, 'path': '/mnt/c/Windows/Fonts/cambriai.ttf'}
# {'index': 142, 'path': '/mnt/c/Windows/Fonts/cambriaz.ttf'}
# {'index': 143, 'path': '/mnt/c/Windows/Fonts/Candara.ttf'}
# {'index': 144, 'path': '/mnt/c/Windows/Fonts/Candarab.ttf'}
# {'index': 145, 'path': '/mnt/c/Windows/Fonts/Candarai.ttf'}
# {'index': 146, 'path': '/mnt/c/Windows/Fonts/Candaral.ttf'}
# {'index': 147, 'path': '/mnt/c/Windows/Fonts/Candarali.ttf'}
# {'index': 148, 'path': '/mnt/c/Windows/Fonts/Candaraz.ttf'}
# {'index': 149, 'path': '/mnt/c/Windows/Fonts/CascadiaCode.ttf'}
# {'index': 150, 'path': '/mnt/c/Windows/Fonts/CascadiaMono.ttf'}
# {'index': 151, 'path': '/mnt/c/Windows/Fonts/comic.ttf'}
# {'index': 152, 'path': '/mnt/c/Windows/Fonts/comicbd.ttf'}
# {'index': 153, 'path': '/mnt/c/Windows/Fonts/comici.ttf'}
# {'index': 154, 'path': '/mnt/c/Windows/Fonts/comicz.ttf'}
# {'index': 155, 'path': '/mnt/c/Windows/Fonts/consola.ttf'}
# {'index': 156, 'path': '/mnt/c/Windows/Fonts/consolab.ttf'}
# {'index': 157, 'path': '/mnt/c/Windows/Fonts/consolai.ttf'}
# {'index': 158, 'path': '/mnt/c/Windows/Fonts/consolaz.ttf'}
# {'index': 159, 'path': '/mnt/c/Windows/Fonts/constan.ttf'}
# {'index': 160, 'path': '/mnt/c/Windows/Fonts/constanb.ttf'}
# {'index': 161, 'path': '/mnt/c/Windows/Fonts/constani.ttf'}
# {'index': 162, 'path': '/mnt/c/Windows/Fonts/constanz.ttf'}
# {'index': 163, 'path': '/mnt/c/Windows/Fonts/corbel.ttf'}
# {'index': 164, 'path': '/mnt/c/Windows/Fonts/corbelb.ttf'}
# {'index': 165, 'path': '/mnt/c/Windows/Fonts/corbeli.ttf'}
# {'index': 166, 'path': '/mnt/c/Windows/Fonts/corbell.ttf'}
# {'index': 167, 'path': '/mnt/c/Windows/Fonts/corbelli.ttf'}
# {'index': 168, 'path': '/mnt/c/Windows/Fonts/corbelz.ttf'}
# {'index': 169, 'path': '/mnt/c/Windows/Fonts/cour.ttf'}
# {'index': 170, 'path': '/mnt/c/Windows/Fonts/courbd.ttf'}
# {'index': 171, 'path': '/mnt/c/Windows/Fonts/courbi.ttf'}
# {'index': 172, 'path': '/mnt/c/Windows/Fonts/couri.ttf'}
# {'index': 173, 'path': '/mnt/c/Windows/Fonts/ebrima.ttf'}
# {'index': 174, 'path': '/mnt/c/Windows/Fonts/ebrimabd.ttf'}
# {'index': 175, 'path': '/mnt/c/Windows/Fonts/framd.ttf'}
# {'index': 176, 'path': '/mnt/c/Windows/Fonts/framdit.ttf'}
# {'index': 177, 'path': '/mnt/c/Windows/Fonts/Gabriola.ttf'}
# {'index': 178, 'path': '/mnt/c/Windows/Fonts/gadugi.ttf'}
# {'index': 179, 'path': '/mnt/c/Windows/Fonts/gadugib.ttf'}
# {'index': 180, 'path': '/mnt/c/Windows/Fonts/georgia.ttf'}
# {'index': 181, 'path': '/mnt/c/Windows/Fonts/georgiab.ttf'}
# {'index': 182, 'path': '/mnt/c/Windows/Fonts/georgiai.ttf'}
# {'index': 183, 'path': '/mnt/c/Windows/Fonts/georgiaz.ttf'}
# {'index': 184, 'path': '/mnt/c/Windows/Fonts/himalaya.ttf'}
# {'index': 185, 'path': '/mnt/c/Windows/Fonts/holomdl2.ttf'}
# {'index': 186, 'path': '/mnt/c/Windows/Fonts/impact.ttf'}
# {'index': 187, 'path': '/mnt/c/Windows/Fonts/Inkfree.ttf'}
# {'index': 188, 'path': '/mnt/c/Windows/Fonts/javatext.ttf'}
# {'index': 189, 'path': '/mnt/c/Windows/Fonts/LeelaUIb.ttf'}
# {'index': 190, 'path': '/mnt/c/Windows/Fonts/LeelawUI.ttf'}
# {'index': 191, 'path': '/mnt/c/Windows/Fonts/LeelUIsl.ttf'}
# {'index': 192, 'path': '/mnt/c/Windows/Fonts/lucon.ttf'}
# {'index': 193, 'path': '/mnt/c/Windows/Fonts/l_10646.ttf'}
# {'index': 194, 'path': '/mnt/c/Windows/Fonts/malgun.ttf'}
# {'index': 195, 'path': '/mnt/c/Windows/Fonts/malgunbd.ttf'}
# {'index': 196, 'path': '/mnt/c/Windows/Fonts/malgunsl.ttf'}
# {'index': 197, 'path': '/mnt/c/Windows/Fonts/marlett.ttf'}
# {'index': 198, 'path': '/mnt/c/Windows/Fonts/micross.ttf'}
# {'index': 199, 'path': '/mnt/c/Windows/Fonts/mmrtext.ttf'}
# {'index': 200, 'path': '/mnt/c/Windows/Fonts/mmrtextb.ttf'}
# {'index': 201, 'path': '/mnt/c/Windows/Fonts/monbaiti.ttf'}
# {'index': 202, 'path': '/mnt/c/Windows/Fonts/msyi.ttf'}
# {'index': 203, 'path': '/mnt/c/Windows/Fonts/mvboli.ttf'}
# {'index': 204, 'path': '/mnt/c/Windows/Fonts/Nirmala.ttf'}
# {'index': 205, 'path': '/mnt/c/Windows/Fonts/NirmalaB.ttf'}
# {'index': 206, 'path': '/mnt/c/Windows/Fonts/NirmalaS.ttf'}
# {'index': 207, 'path': '/mnt/c/Windows/Fonts/ntailu.ttf'}
# {'index': 208, 'path': '/mnt/c/Windows/Fonts/ntailub.ttf'}
# {'index': 209, 'path': '/mnt/c/Windows/Fonts/pala.ttf'}
# {'index': 210, 'path': '/mnt/c/Windows/Fonts/palab.ttf'}
# {'index': 211, 'path': '/mnt/c/Windows/Fonts/palabi.ttf'}
# {'index': 212, 'path': '/mnt/c/Windows/Fonts/palai.ttf'}
# {'index': 213, 'path': '/mnt/c/Windows/Fonts/phagspa.ttf'}
# {'index': 214, 'path': '/mnt/c/Windows/Fonts/phagspab.ttf'}
# {'index': 215, 'path': '/mnt/c/Windows/Fonts/segmdl2.ttf'}
# {'index': 216, 'path': '/mnt/c/Windows/Fonts/segoepr.ttf'}
# {'index': 217, 'path': '/mnt/c/Windows/Fonts/segoeprb.ttf'}
# {'index': 218, 'path': '/mnt/c/Windows/Fonts/segoesc.ttf'}
# {'index': 219, 'path': '/mnt/c/Windows/Fonts/segoescb.ttf'}
# {'index': 220, 'path': '/mnt/c/Windows/Fonts/segoeui.ttf'}
# {'index': 221, 'path': '/mnt/c/Windows/Fonts/segoeuib.ttf'}
# {'index': 222, 'path': '/mnt/c/Windows/Fonts/segoeuii.ttf'}
# {'index': 223, 'path': '/mnt/c/Windows/Fonts/segoeuil.ttf'}
# {'index': 224, 'path': '/mnt/c/Windows/Fonts/segoeuisl.ttf'}
# {'index': 225, 'path': '/mnt/c/Windows/Fonts/segoeuiz.ttf'}
# {'index': 226, 'path': '/mnt/c/Windows/Fonts/seguibl.ttf'}
# {'index': 227, 'path': '/mnt/c/Windows/Fonts/seguibli.ttf'}
# {'index': 228, 'path': '/mnt/c/Windows/Fonts/seguiemj.ttf'}
# {'index': 229, 'path': '/mnt/c/Windows/Fonts/seguihis.ttf'}
# {'index': 230, 'path': '/mnt/c/Windows/Fonts/seguili.ttf'}
# {'index': 231, 'path': '/mnt/c/Windows/Fonts/seguisb.ttf'}
# {'index': 232, 'path': '/mnt/c/Windows/Fonts/seguisbi.ttf'}
# {'index': 233, 'path': '/mnt/c/Windows/Fonts/seguisli.ttf'}
# {'index': 234, 'path': '/mnt/c/Windows/Fonts/seguisym.ttf'}
# {'index': 235, 'path': '/mnt/c/Windows/Fonts/simsunb.ttf'}
# {'index': 236, 'path': '/mnt/c/Windows/Fonts/sylfaen.ttf'}
# {'index': 237, 'path': '/mnt/c/Windows/Fonts/symbol.ttf'}
# {'index': 238, 'path': '/mnt/c/Windows/Fonts/tahoma.ttf'}
# {'index': 239, 'path': '/mnt/c/Windows/Fonts/tahomabd.ttf'}
# {'index': 240, 'path': '/mnt/c/Windows/Fonts/taile.ttf'}
# {'index': 241, 'path': '/mnt/c/Windows/Fonts/taileb.ttf'}
# {'index': 242, 'path': '/mnt/c/Windows/Fonts/times.ttf'}
# {'index': 243, 'path': '/mnt/c/Windows/Fonts/timesbd.ttf'}
# {'index': 244, 'path': '/mnt/c/Windows/Fonts/timesbi.ttf'}
# {'index': 245, 'path': '/mnt/c/Windows/Fonts/timesi.ttf'}
# {'index': 246, 'path': '/mnt/c/Windows/Fonts/trebuc.ttf'}
# {'index': 247, 'path': '/mnt/c/Windows/Fonts/trebucbd.ttf'}
# {'index': 248, 'path': '/mnt/c/Windows/Fonts/trebucbi.ttf'}
# {'index': 249, 'path': '/mnt/c/Windows/Fonts/trebucit.ttf'}
# {'index': 250, 'path': '/mnt/c/Windows/Fonts/verdana.ttf'}
# {'index': 251, 'path': '/mnt/c/Windows/Fonts/verdanab.ttf'}
# {'index': 252, 'path': '/mnt/c/Windows/Fonts/verdanai.ttf'}
# {'index': 253, 'path': '/mnt/c/Windows/Fonts/verdanaz.ttf'}
# {'index': 254, 'path': '/mnt/c/Windows/Fonts/webdings.ttf'}
# {'index': 255, 'path': '/mnt/c/Windows/Fonts/wingding.ttf'}

# %% [markdown]
# ## Random

# %%
def get_generator():
    generator = SystemRandom()
    return generator

# %%
output_dir: str = '/tmp/symbols'
margin: int = 200

def select_subsampling() -> int:
    generator = get_generator()
    return generator.randint(0, 1)

def select_font() -> str:
    global fonts
    generator = get_generator()

    last_position: int = len(fonts) - 1
    return fonts[generator.randint(0, last_position)]

def select_font_size() -> int:
    global height
    generator = get_generator()
    return generator.randint(48, height)

def select_text_position_x() -> int:
    global width, margin
    generator = get_generator()
    return generator.randint(0, (width - margin))

def select_text_position_y() -> int:
    global height, margin
    generator = get_generator()
    return generator.randint(0, (height - margin))

def select_text_position() -> tuple:
    return (
        select_text_position_x(), 
        select_text_position_y()
    )

def select_value_in_color_spectrum() -> int:
    generator = get_generator()
    return generator.randint(0, 255)

def select_quality() -> int:
    return get_generator().randint(
        1, 
        100
    )

def select_random_color() -> tuple:
    generator = get_generator()

    red: int = select_value_in_color_spectrum()
    green: int = select_value_in_color_spectrum()
    blue: int = select_value_in_color_spectrum()

    return (red, green, blue)

# %%
def make_random_noise_bw_background( 
    image:Image 
) -> Image:
    random = SystemRandom()

    width, height = image.size
    pixels = image.load()

    for y in range(height):
        for x in range(width):
            red, green, blue = pixels[x, y]

            value: int = random.randint(0, 255)

            red = value
            green = value
            blue = value

            pixels[x, y] = (red, green, blue)

    return image

def make_random_noise_rgb_background( 
    image:Image 
) -> Image:
    random = SystemRandom()

    width, height = image.size
    pixels = image.load()

    for y in range(height):
        for x in range(width):
            red, green, blue = pixels[x, y]

            red = random.randint(0, 255)
            green = random.randint(0, 255)
            blue = random.randint(0, 255)

            pixels[x, y] = (red, green, blue)
    return image

# %%
def generate_random_image(
        black_and_white_background: bool = False
):
    with new(
        'RGB', 
        size=dimensions, 
        color='white'
    ) as creation:
        
        if black_and_white_background:
            creation = make_random_noise_bw_background(
                creation
            )
        else:
            creation = make_random_noise_rgb_background(
                creation
            )

        canvas = ImageDraw.Draw(
            creation
        )
        
        size: int = select_font_size()
        font =  ImageFont.truetype(
            select_font(), 
            size
        )

        canvas.text(
            select_text_position(), 
            "A", 
            font=font, 
            fill=select_random_color()
        )

        image = creation.copy()
        return image

# %%
processes: int = 8
number_of_batches: int = 1000
batches_per_process: int = int(number_of_batches/processes)

generated_list: list = list()
sizes: list = list()

def get_result_images() -> list:
    global generated_list
    return generated_list

print(processes, number_of_batches, batches_per_process)

for i in range(
    processes
):
    result: int = i * batches_per_process
    sizes.append(
        result
    )
# Out:
# 8 1000 125

# %%
def append_image_to_generated(
        image: Image
) -> None:
    list_of_images = get_result_images()
    list_of_images.append(
        image
    )

def generate(
        size: int
) -> list | None:
    global batches_per_process

    result: list = list()

    begin = size
    end = size + batches_per_process

    for i in range(
        begin, 
        end
    ):
        black_and_white = bool(
            get_generator().getrandbits(
                1
            )
        )

        result.append(
            generate_random_image(
                black_and_white
            )
        )
    
    return result

# %%
is_done = None

with Pool(
    processes
) as p:
    r = p.map(
        generate, 
        sizes
    )

    is_done = r.copy()

generated_list: list = list()

if not (is_done is None):
    for t in range(len(is_done)):
        for x in range(len(is_done[t])):
            selected = is_done[t][x]
            append_image_to_generated(
                selected.copy()
            )

is_done = None

def size_of_result_images() -> int:
    return len(
        get_result_images()
    )

# %%
size_of_output: int = len(listdir(output_dir))
counter: int = size_of_output

for i in range(size_of_result_images()):
    counter = counter + 1
    image = generated_list[i]

    full_path: str = join(
        output_dir, 
        str(str(counter) + '.jpg')
    )

    image.save(
        full_path,
        quality=select_quality(),
        subsampling=select_subsampling()
    )
